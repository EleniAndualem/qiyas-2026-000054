# %%
#importing our libraries
from bs4 import BeautifulSoup
import pandas as pd
import requests

# %%
BBC_URL = "https://www.bbc.com/news/topics/cwlw3xz047jt"
HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36",
    "Accept-Language": "en-US,en;q=0.9",
}

# %%
Articles = []

for page in range(1,43):
    print(f"Fetching Page {page} ...")
    url = BBC_URL if page == 1 else f"{BBC_URL}?page={page}"
    
    htmlDoc = requests.get(url, headers=HEADERS)
    soup = BeautifulSoup(htmlDoc.content, "html.parser")

    articles = soup.find_all("a", {"data-testid": "internal-link"}) or soup.find_all("a", href=True)

    for article in articles:
        href = article.get("href")
        if not href or not any(path in href for path in ["/news/articles/", "/news/world-", "/news/blogs"]):
            continue

        title_tag = article.find("h2") or article.find("span")
        title = title_tag.text.strip() if title_tag else "No Title"
        article_link = href if href.startswith("http") else f"https://www.bbc.com{href}"

        description_tag = article.find("p")
        description = description_tag.text.strip() if description_tag else "No Description"

        # Article Details page
        articleDetailPage = requests.get(article_link, headers=HEADERS)
        article_soup = BeautifulSoup(articleDetailPage.content, "html.parser")

        # Banner Image 
        og_tag = article_soup.find("meta", property="og:image") or article_soup.find("meta", attrs={"name": "og:image"})
        banner = og_tag.get("content") if og_tag else "No Banner Image"

        # Author and Contributor
        author_tag = article_soup.select_one('span[class*="AuthorNameStyled"]')
        contrib_tag = article_soup.select_one('span[data-testid*="role-location"]')

        author = author_tag.text.strip() if author_tag else "Unknown"
        contributor = contrib_tag.text.strip() if contrib_tag else "Unknown"

        # Main Content Block Extraction 
        body = article_soup.find("article") or article_soup
        text_blocks = body.select('div[data-component="text-block"] p')
        content_segments = [p.text.strip() for p in text_blocks if p.text.strip()]

        Articles.append({
            "Title": title,
            "Description": description,
            "Link": article_link,
            "Banner Image": banner,
            "Author": author,
            "Contributor": contributor,
            "Content": "\n\n".join(content_segments) or "No content found",
        })

print("\n Done!")
# Out:
# Fetching Page 1 ...
# Fetching Page 2 ...
# Fetching Page 3 ...
# Fetching Page 4 ...
# Fetching Page 5 ...
# Fetching Page 6 ...
# Fetching Page 7 ...
# Fetching Page 8 ...
# Fetching Page 9 ...
# Fetching Page 10 ...
# Fetching Page 11 ...
# Fetching Page 12 ...
# Fetching Page 13 ...
# Fetching Page 14 ...
# Fetching Page 15 ...
# Fetching Page 16 ...
# Fetching Page 17 ...
# Fetching Page 18 ...
# Fetching Page 19 ...
# Fetching Page 20 ...
# Fetching Page 21 ...
# Fetching Page 22 ...
# Fetching Page 23 ...
# Fetching Page 24 ...
# Fetching Page 25 ...
# Fetching Page 26 ...
# Fetching Page 27 ...
# Fetching Page 28 ...
# Fetching Page 29 ...
# Fetching Page 30 ...
# Fetching Page 31 ...
# Fetching Page 32 ...
# Fetching Page 33 ...
# Fetching Page 34 ...
# Fetching Page 35 ...
# Fetching Page 36 ...
# Fetching Page 37 ...
# Fetching Page 38 ...
# Fetching Page 39 ...
# Fetching Page 40 ...
# Fetching Page 41 ...
# Fetching Page 42 ...
#
#  Done!

# %%
df = pd.DataFrame(Articles)
df
# Out:
#                                                  Title  \
# 0    Voting suspended in parts of Ethiopia over sec...
# 1    I moved from Ethiopia to Shetland - and I've b...
# 2    Ethiopian woman's joy at rare quintuplets afte...
# 3    Millions listen to Ethiopian star's song takin...
# 4    Ringleader of suspected human trafficking netw...
# ..                                                 ...
# 342  Seismic change: How Covid-19 altered world eve...
# 343    Somalia's Christmas birthdays and lost memories
# 344   Ethiopia military 'kills 40 after 100 massacred'
# 345          Attackers kill dozens in western Ethiopia
# 346  'Abandoned' bomb kills three in Ethiopia's cap...
#
#                                            Description  \
# 0    Prime Minister Abiy Ahmed's party is expected ...
# 1    Netsanet Sori is bringing a flavour of the far...
# 2    The woman, 35, says she was praying for a baby...
# 3    The country's biggest musician Teddy Afro lame...
# ...

# %%
# exporting our dataframe into a csv file
df.to_csv("bbc_news.csv", index=False, encoding="utf-8-sig")
