# %%
studentDict = {
    "id": ("S/001", "S/002", 'S/003'),
    "name": ["Abebe", "Kebede"],
    "gpa": (2.89, 3.67),
    "coursesTook": [
        ["history", "geography"],
        ["physics", "mathematics"]
    ],
    "courseGrade": [
        [67, 79],
        [95, 91]
    ]
}

studentDict
# Out:
# {'id': ('S/001', 'S/002', 'S/003'),
#  'name': ['Abebe', 'Kebede'],
#  'gpa': (2.89, 3.67),
#  'coursesTook': [['history', 'geography'], ['physics', 'mathematics']],
#  'courseGrade': [[67, 79], [95, 91]]}

# %%
studentDict.keys()
# Out:
# dict_keys(['id', 'name', 'gpa', 'coursesTook', 'courseGrade'])

# %%
print(len(studentDict))
# Out:
# 5

# %%
print(type(studentDict))
# Out:
# <class 'dict'>

# %%
studentDict["id"].append("S/003")

# %%
studentDict
# Out:
# {'id': ['S/001', 'S/002', 'S/003'],
#  'name': ['Abebe', 'Kebede'],
#  'gpa': (2.89, 3.67),
#  'coursesTook': [['history', 'geography'], ['physics', 'mathematics']],
#  'courseGrade': [[67, 79], [95, 91]]}

# %%
studentDict["name"].append("chala")

# %%
studentDict
# Out:
# {'id': ('S/001', 'S/002', 'S/003'),
#  'name': ['Abebe', 'Kebede', 'chala', 'chala'],
#  'gpa': (2.89, 3.67),
#  'coursesTook': [['history', 'geography'], ['physics', 'mathematics']],
#  'courseGrade': [[67, 79], [95, 91]]}

# %%
myPara=("Video provides a powerful way to help you prove your point. When you click Online Video, you can paste in the embed code for the video you want to add. You can also type a keyword to search online for the video that best fits your document. To make your document look professionally produced, Word provides header, footer, cover page, and text box designs that complement each other. For example, you can add a matching cover page, header, and sidebar. Click Insert and then choose the elements you want from the different galleries. Themes and styles also help keep your document coordinated. When you click Design and choose a new Theme, the pictures, charts, and SmartArt graphics change to match your new theme. When you apply styles, your headings change to match the new theme. Save time in Word with new buttons that show up where you need them.")

# %%
print(myPara)
# Out:
# Video provides a powerful way to help you prove your point. When you click Online Video, you can paste in the embed code for the video you want to add. You can also type a keyword to search online for the video that best fits your document. To make your document look professionally produced, Word provides header, footer, cover page, and text box designs that complement each other. For example, you can add a matching cover page, header, and sidebar. Click Insert and then choose the elements you want from the different galleries. Themes and styles also help keep your document coordinated. When you click Design and choose a new Theme, the pictures, charts, and SmartArt graphics change to match your new theme. When you apply styles, your headings change to match the new theme. Save time in Word with new buttons that show up where you need them.

# %%
myParaList=myPara.lower().split()
myParaList
# Out:
# ['video',
#  'provides',
#  'a',
#  'powerful',
#  'way',
#  'to',
#  'help',
#  'you',
#  'prove',
#  'your',
#  'point.',
#  'when',
#  'you',
#  'click',
#  'online',
#  'video,',
#  'you',
#  'can',
#  'paste',
#  'in',
#  'the',
#  'embed',
#  'code',
#  'for',
#  'the',
#  'video',
#  'you',
#  'want',
#  'to',
#  'add.',
#  'you',
#  'can',
#  'also',
#  'type',
#  'a',
#  'keyword',
#  'to',
#  'search',
#  'online',
#  'for',
#  'the',
#  'video',
#  'that',
#  'best',
#  'fits',
#  'your',
#  'document.',
#  'to',
#  'make',
#  'your',
#  'document',
#  'look',
#  'professionally',
#  'produced,',
#  'word',
#  'provides',
#  'header,',
#  'footer,',
#  'cover',
#  'page,',
#  'and',
#  'text',
#  'box',
#  'designs',
#  'that',
#  'complement',
#  'each',
#  'other.',
#  'for',
#  'example,',
#  'you',
#  'can',
#  'add',
#  'a',
#  'matching',
#  'cover',
#  'page,',
#  'header,',
#  'and',
#  'sidebar.',
#  'click',
#  'insert',
#  'and',
#  'then',
#  'choose',
# ...

# %%
myParaList.count("a")
# Out:
# 4

# %%
myParaList.count("in")
# Out:
# 2

# %%
myParaList.count("the")
# Out:
# 7

# %%
myParaList.sort()
myParaList
# Out:
# ['a',
#  'a',
#  'a',
#  'a',
#  'add',
#  'add.',
#  'also',
#  'also',
#  'and',
#  'and',
#  'and',
#  'and',
#  'and',
#  'and',
#  'apply',
#  'best',
#  'box',
#  'buttons',
#  'can',
#  'can',
#  'can',
#  'change',
#  'change',
#  'charts,',
#  'choose',
#  'choose',
#  'click',
#  'click',
#  'click',
#  'code',
#  'complement',
#  'coordinated.',
#  'cover',
#  'cover',
#  'design',
#  'designs',
#  'different',
#  'document',
#  'document',
#  'document.',
#  'each',
#  'elements',
#  'embed',
#  'example,',
#  'fits',
#  'footer,',
#  'for',
#  'for',
#  'for',
#  'from',
#  'galleries.',
#  'graphics',
#  'header,',
#  'header,',
#  'headings',
#  'help',
#  'help',
#  'in',
#  'in',
#  'insert',
#  'keep',
#  'keyword',
#  'look',
#  'make',
#  'match',
#  'match',
#  'matching',
#  'need',
#  'new',
#  'new',
#  'new',
#  'new',
#  'online',
#  'online',
#  'other.',
#  'page,',
#  'page,',
#  'paste',
#  'pictures,',
#  'point.',
#  'powerful',
#  'produced,',
# ...

# %%
myParaList=myPara.replace(".","").replace(",","").lower().split()
myParaList
# Out:
# ['video',
#  'provides',
#  'a',
#  'powerful',
#  'way',
#  'to',
#  'help',
#  'you',
#  'prove',
#  'your',
#  'point',
#  'when',
#  'you',
#  'click',
#  'online',
#  'video',
#  'you',
#  'can',
#  'paste',
#  'in',
#  'the',
#  'embed',
#  'code',
#  'for',
#  'the',
#  'video',
#  'you',
#  'want',
#  'to',
#  'add',
#  'you',
#  'can',
#  'also',
#  'type',
#  'a',
#  'keyword',
#  'to',
#  'search',
#  'online',
#  'for',
#  'the',
#  'video',
#  'that',
#  'best',
#  'fits',
#  'your',
#  'document',
#  'to',
#  'make',
#  'your',
#  'document',
#  'look',
#  'professionally',
#  'produced',
#  'word',
#  'provides',
#  'header',
#  'footer',
#  'cover',
#  'page',
#  'and',
#  'text',
#  'box',
#  'designs',
#  'that',
#  'complement',
#  'each',
#  'other',
#  'for',
#  'example',
#  'you',
#  'can',
#  'add',
#  'a',
#  'matching',
#  'cover',
#  'page',
#  'header',
#  'and',
#  'sidebar',
#  'click',
#  'insert',
#  'and',
#  'then',
#  'choose',
#  'the',
# ...

# %%
myParaDict = {}
for word in myParaList:
    if word in myParaDict:
        myParaDict[word] = myParaDict[word] + 1
    else:
        myParaDict[word] = 1
myParaDict
# Out:
# {'video': 4,
#  'provides': 2,
#  'a': 4,
#  'powerful': 1,
#  'way': 1,
#  'to': 6,
#  'help': 2,
#  'you': 10,
#  'prove': 1,
#  'your': 6,
#  'point': 1,
#  'when': 3,
#  'click': 3,
#  'online': 2,
#  'can': 3,
#  'paste': 1,
#  'in': 2,
#  'the': 7,
#  'embed': 1,
#  'code': 1,
#  'for': 3,
#  'want': 2,
#  'add': 2,
#  'also': 2,
#  'type': 1,
#  'keyword': 1,
#  'search': 1,
#  'that': 3,
#  'best': 1,
#  'fits': 1,
#  'document': 3,
#  'make': 1,
#  'look': 1,
#  'professionally': 1,
#  'produced': 1,
#  'word': 2,
#  'header': 2,
#  'footer': 1,
#  'cover': 2,
#  'page': 2,
#  'and': 6,
#  'text': 1,
#  'box': 1,
#  'designs': 1,
#  'complement': 1,
#  'each': 1,
#  'other': 1,
#  'example': 1,
#  'matching': 1,
#  'sidebar': 1,
#  'insert': 1,
#  'then': 1,
#  'choose': 2,
#  'elements': 1,
#  'from': 1,
#  'different': 1,
#  'galleries': 1,
#  'themes': 1,
#  'styles': 2,
#  'keep': 1,
#  'coordinated': 1,
#  'design': 1,
#  'new': 4,
#  'theme': 3,
#  'pictures': 1,
# ...

# %%
result = myParaFunc(myParaList)
print(result)
# Out:
# {'video': 4, 'provides': 2, 'a': 4, 'powerful': 1, 'way': 1, 'to': 6, 'help': 2, 'you': 10, 'prove': 1, 'your': 6, 'point': 1, 'when': 3, 'click': 3, 'online': 2, 'can': 3, 'paste': 1, 'in': 2, 'the': 7, 'embed': 1, 'code': 1, 'for': 3, 'want': 2, 'add': 2, 'also': 2, 'type': 1, 'keyword': 1, 'search': 1, 'that': 3, 'best': 1, 'fits': 1, 'document': 3, 'make': 1, 'look': 1, 'professionally': 1, 'produced': 1, 'word': 2, 'header': 2, 'footer': 1, 'cover': 2, 'page': 2, 'and': 6, 'text': 1, 'box': 1, 'designs': 1, 'complement': 1, 'each': 1, 'other': 1, 'example': 1, 'matching': 1, 'sidebar': 1, 'insert': 1, 'then': 1, 'choose': 2, 'elements': 1, 'from': 1, 'different': 1, 'galleries': 1, 'themes': 1, 'styles': 2, 'keep': 1, 'coordinated': 1, 'design': 1, 'new': 4, 'theme': 3, 'pictures': 1, 'charts': 1, 'smartart': 1, 'graphics': 1, 'change': 2, 'match': 2, 'apply': 1, 'headings': 1, 'save': 1, 'time': 1, 'with': 1, 'buttons': 1, 'show': 1, 'up': 1, 'where': 1, 'need': 1, 'them': 1}

# %%
#Link
file=open("qiyas.txt", 'a' ,encoding='utf-8')

# %%
for data in range(1,15):
    print( data + data**2 + data**3+ data**4 )
# Out:
# 4
# 30
# 120
# 340
# 780
# 1554
# 2800
# 4680
# 7380
# 11110
# 16104
# 22620
# 30940
# 41370

# %%
for data in range(1, 15):
    line = f"{data}\n{data**2}\n{data**3}\n{data**4}"
    file.write(line)

# %%
file.close()

# %%
file_read = open("qiyas.txt", 'r' , encoding ='utf-8')
print(file_read.read())
file_read.close()
# Out:
# 1
# 1
# 1
# 12
# 4
# 8
# 163
# 9
# 27
# 814
# 16
# 64
# 2565
# 25
# 125
# 6256
# 36
# 216
# 12967
# 49
# 343
# 24018
# 64
# 512
# 40969
# 81
# 729
# 656110
# 100
# 1000
# 1000011
# 121
# 1331
# 1464112
# 144
# 1728
# 2073613
# 169
# 2197
# 2856114
# 196
# 2744
# 38416
