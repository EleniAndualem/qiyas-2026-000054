# %%
#list compression
nums =[1,2,3,4,5]
myFunc = [value**2 for value in nums]
print (myFunc)

# %%
#lamda/anonymous
multiply = lambda x, y=3 : x * y
print(multiply(5))

# %%
#lamda
multiply = lambda x, y: x * y
print(multiply(5,6))

# %%
#default arg
def mypython (x,y=2):
    print (x/y)

# %%
mypython (4)

# %%
def mypython (x,y):
    print (x**y)

# %%
mypython (2,3)

# %%
def myFunc(x):
    x[0]=20
lst =[10,20,30,40]
myFunc(lst)
print(lst)
# Out:
# [20, 20, 30, 40]

# %%
mtx= [ ["q", "z"] , ["a","h"] , ["c","l"]]
res=[letters for row in mtx for letters in row]
res

# %%
res.count('a')

# %%
res.sort()
res

# %%
res[2] ="b"

# %%
res=[]
for val in range(1,6):
    res.append(val*2)
    print(res)
# Out:
# [2]
# [2, 4]
# [2, 4, 6]
# [2, 4, 6, 8]
# [2, 4, 6, 8, 10]

# %%
c=[(x,y) for x in range (1,3) for y in range (1,3)]
print(c)
# Out:
# [(1, 1), (1, 2), (2, 1), (2, 2)]

# %%
a= [val for row in c for val in row]
print (a)
# Out:
# [1, 1, 1, 2, 2, 1, 2, 2]

# %%
a.count(1)
# Out:
# 4

# %%
a.sort()
a
# Out:
# [1, 1, 1, 1, 2, 2, 2, 2]

# %%
uni= 'addis ababa university'
upper = lambda x: x.upper()
print (upper(uni))
# Out:
# ADDIS ABABA UNIVERSITY

# %%
check= lambda x:"+" if x>0 else "-" if x<0 else "0"

print(check(1))
print(check(-1))
print(check(0))
# Out:
# +
# -
# 0

# %%
myNums = [lambda arg=x* 10 for x in range(5)]
for i in myNums:
    print (i())
# Out:
#   Cell In[31], line 1
#     myNums = [lambda arg=x*10 for x in range(5)]
#                               ^
# SyntaxError: invalid syntax
