# %%
pip install dash plotly pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import dash
from dash import dcc, html
from dash.dependencies import Input, Output
import plotly.express as px
import pandas as pd

# %%
app = dash.Dash(__name__)

# Get unique genres
genres = sorted(cleanedTable["genre"].dropna().unique())

app.layout = html.Div([
    html.H1("Movie Score Analysis by Genre"),

    dcc.Dropdown(
        id="genre-dropdown",
        options=[{"label": g, "value": g} for g in genres],
        value=genres[0],
        clearable=False,
        style={"width": "50%"}
    ),

    dcc.Graph(id="score-graph")
])


@app.callback(
    Output("score-graph", "figure"),
    Input("genre-dropdown", "value")
)
def update_graph(selected_genre):

    # Filter selected genre
    df = cleanedTable[cleanedTable["genre"] == selected_genre]

    # Average score by rating
    avg_score = (
        df.groupby("rating")["score"]
        .mean()
        .reset_index()
    )

    fig = px.bar(
        avg_score,
        x="rating",
        y="score",
        title=f"Average Movie Score by Rating ({selected_genre})",
        labels={
            "rating": "Movie Rating",
            "score": "Average Score"
        }
    )

    return fig


if __name__ == "__main__":
    app.run(debug=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import dash
#       2 from dash import dcc, html
#       3 from dash.dependencies import Input, Output
#
# ModuleNotFoundError: No module named 'dash'
